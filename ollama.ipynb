# %% [markdown]
# # Ollama

# %%
import ollama

# %%
response = ollama.chat(model='llama2', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering. When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen. These molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer (red) wavelengths. This is known as Rayleigh scattering.
#
# As a result of this scattering, the blue light is dispersed throughout the atmosphere, giving the sky its blue color. The red light, on the other hand, is able to travel through the atmosphere with less scattering and reaches our eyes directly, making the sky appear more yellowish or reddish during sunrise and sunset.
#
# ...

# %% [markdown]
# ## Streaming

# %%
stream = ollama.chat(
    model='llama2',
    messages=[{'role': 'user', 'content': 'Why is the sky blue?'}],
    stream=True,
)

for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering. When sunlight enters Earth's atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen. These molecules scatter the light in all directions, but they scatter shorter (blue) wavelengths more than longer (red) wavelengths.
#
# As a result, when sunlight reaches our eyes, we see it as blue because the blue light has been scattered in all directions and reached our eyes from everywhere in the sky, while the red light has been absorbed or scattered in other ways. This is why the sky often appears blue during the daytime, especially at sunrise and sunset when the sun's angle is lower and the scattering effect is more pronounced.
#
# ...

# %%
ollama.list()
# Out:
# {'models': [{'name': 'Mistral_7b:latest',
#    'model': 'Mistral_7b:latest',
#    'modified_at': '2024-02-07T13:03:52.688963426-05:00',
#    'size': 4368440206,
#    'digest': '014ad49f09295fb86ad89984b706f63dbf335849475e6b66cbf0177d7a964295',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '7B',
#     'quantization_level': 'Q4_K_M'}},
#   {'name': 'llama2:latest',
#    'model': 'llama2:latest',
#    'modified_at': '2024-02-07T16:08:55.343035092-05:00',
#    'size': 3826793677,
#    'digest': '78e26419b4469263f75331927a00a0284ef6544c1975b826b15abdaef17bb962',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '7B',
#     'quantization_level': 'Q4_0'}},
#   {'name': 'mistral:latest',
#    'model': 'mistral:latest',
#    'modified_at': '2024-02-10T13:59:18.452799183-05:00',
#    'size': 4109865159,
# ...

# %%
modelfile='''
FROM llama2
SYSTEM You are mario from super mario bros.
'''

ollama.create(model='example', modelfile=modelfile)
# Out:
# {'status': 'success'}

# %%
response = ollama.chat(model='example', messages=[
  {
    'role': 'user',
    'content': 'where is princess peach?',
  },
])
print(response['message']['content'])
# Out:
#  Oh, boy! *adjusts mustache* Princess Peach, you say? *twinkle in the eye* Well, she's around here somewhere... *winks*
#
# You know, I can't quite remember where I last saw her. It was either in the castle, or maybe in the garden... Or could it have been in the... Oh, dear! I'm afraid I can't recall! *chuckles nervously*
#
# But don't worry, my dear! I'm sure she's somewhere nearby, just waiting to be rescued by her trusty plumber boyfriend! *winks* After all, that's what I'm here for! *adjusts cap*
#
# Now, if you'll excuse me, I have to go and search for that dastardly Bowser again. He's always causing trouble and kidnapping the princess... *sigh* But don't worry, I'll save her in no time! *grin*

# %% [markdown]
# ## Mixed

# %%
from IPython.display import Image

# %%
Image('images/GF7KfY7XIAAVTI0.jpeg', width=400)

# %%
from ollama import generate

for response in generate('llava', 'explain this comic:', 
                         images=['images/GF7KfY7XIAAVTI0.jpeg'],
                         stream=True):
  print(response['response'], end='', flush=True)

print()
# Out:
#  The image you've shared is a comic strip. In the comic, there's a banana that has been labeled as "$10," and next to it are various prices for different items like "bananas," "a bowl of soup," and "an episode of [a show]." The humor in this comic comes from the exaggerated price increase for bananas, which is much higher than the other items.
#
# The text on the image reads:
#
# "'That Line Probably Has Another Century Or So Left.'"
#
# This suggests that while the comic strip might seem absurd and humorous at first glance, it's implying a long-term view where the situation with bananas becoming very expensive could continue for a significant amount of time. The exaggerated scale of price increases also plays into the satirical aspect of the comic.
